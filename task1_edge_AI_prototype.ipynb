# %% [markdown]
# # Task 1: Edge AI Prototype
#
# ## Objective
# Train a lightweight image classification model (e.g., recognizing recyclable items), convert it to TensorFlow Lite, and test it on a sample dataset.
#
# ## Tools
# - TensorFlow Lite
# - Raspberry Pi/Colab (simulation)

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Import necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import pathlib
import os

# %% [markdown]
# ## 2. Data Loading and Preparation

# %%
# Load and preprocess dataset
# TODO: Load recyclable items dataset
# TODO: Split into training and testing sets
# TODO: Preprocess images (resize, normalize)

# %% [markdown]
# ## 3. Model Architecture

# %%
# Create lightweight CNN model for edge deployment
# TODO: Design model architecture with appropriate complexity for edge devices
# TODO: Compile model with appropriate loss function and optimizer

# %% [markdown]
# ## 4. Model Training

# %%
# Train the model
# TODO: Train model with appropriate batch size and epochs
# TODO: Implement callbacks for early stopping and model checkpointing

# %% [markdown]
# ## 5. Model Evaluation

# %%
# Evaluate model performance
# TODO: Evaluate on test set
# TODO: Calculate accuracy metrics
# TODO: Generate confusion matrix

# %% [markdown]
# ## 6. TensorFlow Lite Conversion

# %%
# Convert model to TensorFlow Lite format
# TODO: Convert Keras model to TFLite
# TODO: Optimize model for edge deployment
# TODO: Save TFLite model

# %% [markdown]
# ## 7. Edge AI Testing

# %%
# Test the TensorFlow Lite model
# TODO: Load TFLite model
# TODO: Run inference on sample images
# TODO: Compare results with original model

# %% [markdown]
# ## 8. Edge AI Benefits Analysis

# %%
# Analyze Edge AI benefits for real-time applications
# TODO: Discuss advantages of Edge AI for real-time applications
# TODO: Compare with cloud-based solutions
# TODO: Consider latency, bandwidth, and privacy implications

# %% [markdown]
# ## 9. Results and Deployment Steps

# %%
# Document results and deployment steps
# TODO: Summarize model performance metrics
# TODO: Outline deployment steps for Raspberry Pi or similar device
# TODO: Create deployment checklist
